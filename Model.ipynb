# %%
from google.colab import drive
import os

drive.mount('/content/drive')
# Cài đặt Unsloth và các thư viện cần thiết
# !pip install "unsloth[colab-new] @ git+https://github.com/unslothai/unsloth.git"
# !pip install --no-deps "trl<0.9.0" peft accelerate bitsandbytes xformers
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Collecting unsloth@ git+https://github.com/unslothai/unsloth.git (from unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git)
#   Cloning https://github.com/unslothai/unsloth.git to /tmp/pip-install-889sv5d5/unsloth_d97fc6f8af5949e5b968d53cda77df80
#   Running command git clone --filter=blob:none --quiet https://github.com/unslothai/unsloth.git /tmp/pip-install-889sv5d5/unsloth_d97fc6f8af5949e5b968d53cda77df80
#   Resolved https://github.com/unslothai/unsloth.git to commit a2d7811fe8283475f50c88645fb5d124dedb714c
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: unsloth_zoo>=2025.12.7 in /usr/local/lib/python3.12/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2025.12.7)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (25.0)
# Requirement already satisfied: tyro in /usr/local/lib/python3.12/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (1.0.3)
# Requirement already satisfied: transformers!=4.52.0,!=4.52.1,!=4.52.2,!=4.52.3,!=4.53.0,!=4.54.0,!=4.55.0,!=4.55.1,!=4.57.0,<=4.57.3,>=4.51.3 in /usr/local/lib/python3.12/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (4.57.3)
# Requirement already satisfied: datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1 in /usr/local/lib/python3.12/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (4.3.0)
# Requirement already satisfied: sentencepiece>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.2.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (5.9.5)
# Requirement already satisfied: wheel>=0.42.0 in /usr/local/lib/python3.12/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.45.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2.0.2)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (5.29.5)
# Requirement already satisfied: huggingface_hub>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.36.0)
# Requirement already satisfied: hf_transfer in /usr/local/lib/python3.12/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.1.9)
# Requirement already satisfied: bitsandbytes!=0.46.0,!=0.48.0,>=0.45.5 in /usr/local/lib/python3.12/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.49.0)
# Requirement already satisfied: torch<3,>=2.3 in /usr/local/lib/python3.12/dist-packages (from bitsandbytes!=0.46.0,!=0.48.0,>=0.45.5->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2.9.0+cu126)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.20.0)
# Requirement already satisfied: pyarrow>=21.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (22.0.0)
# Requirement already satisfied: dill<0.4.1,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.12/dist-packages (from datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2.32.4)
# Requirement already satisfied: httpx<1.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.28.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.70.16)
# Requirement already satisfied: fsspec<=2025.9.0,>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.9.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2025.3.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (6.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.34.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.34.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (1.2.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers!=4.52.0,!=4.52.1,!=4.52.2,!=4.52.3,!=4.53.0,!=4.54.0,!=4.55.0,!=4.55.1,!=4.57.0,<=4.57.3,>=4.51.3->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers!=4.52.0,!=4.52.1,!=4.52.2,!=4.52.3,!=4.53.0,!=4.54.0,!=4.55.0,!=4.55.1,!=4.57.0,<=4.57.3,>=4.51.3->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers!=4.52.0,!=4.52.1,!=4.52.2,!=4.52.3,!=4.53.0,!=4.54.0,!=4.55.0,!=4.55.1,!=4.57.0,<=4.57.3,>=4.51.3->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.7.0)
# Requirement already satisfied: torchao>=0.13.0 in /usr/local/lib/python3.12/dist-packages (from unsloth_zoo>=2025.12.7->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.15.0)
# Requirement already satisfied: triton>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from unsloth_zoo>=2025.12.7->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.5.0)
# Requirement already satisfied: accelerate>=0.34.1 in /usr/local/lib/python3.12/dist-packages (from unsloth_zoo>=2025.12.7->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (1.12.0)
# Collecting trl!=0.19.0,<=0.24.0,>=0.18.2 (from unsloth_zoo>=2025.12.7->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git)
#   Using cached trl-0.24.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: peft!=0.11.0,>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from unsloth_zoo>=2025.12.7->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.18.0)
# Requirement already satisfied: cut_cross_entropy in /usr/local/lib/python3.12/dist-packages (from unsloth_zoo>=2025.12.7->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (25.1.1)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from unsloth_zoo>=2025.12.7->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (11.3.0)
# Requirement already satisfied: msgspec in /usr/local/lib/python3.12/dist-packages (from unsloth_zoo>=2025.12.7->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.20.0)
# Requirement already satisfied: docstring-parser>=0.15 in /usr/local/lib/python3.12/dist-packages (from tyro->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.17.0)
# Requirement already satisfied: typeguard>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from tyro->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (4.4.4)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.9.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.13.2)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (4.12.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2.5.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes!=0.46.0,!=0.48.0,>=0.45.5->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes!=0.46.0,!=0.48.0,>=0.45.5->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes!=0.46.0,!=0.48.0,>=0.45.5->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes!=0.46.0,!=0.48.0,>=0.45.5->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes!=0.46.0,!=0.48.0,>=0.45.5->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes!=0.46.0,!=0.48.0,>=0.45.5->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes!=0.46.0,!=0.48.0,>=0.45.5->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes!=0.46.0,!=0.48.0,>=0.45.5->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes!=0.46.0,!=0.48.0,>=0.45.5->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes!=0.46.0,!=0.48.0,>=0.45.5->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes!=0.46.0,!=0.48.0,>=0.45.5->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes!=0.46.0,!=0.48.0,>=0.45.5->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes!=0.46.0,!=0.48.0,>=0.45.5->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes!=0.46.0,!=0.48.0,>=0.45.5->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes!=0.46.0,!=0.48.0,>=0.45.5->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes!=0.46.0,!=0.48.0,>=0.45.5->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes!=0.46.0,!=0.48.0,>=0.45.5->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes!=0.46.0,!=0.48.0,>=0.45.5->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes!=0.46.0,!=0.48.0,>=0.45.5->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (1.11.1.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2025.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (1.22.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch<3,>=2.3->bitsandbytes!=0.46.0,!=0.48.0,>=0.45.5->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch<3,>=2.3->bitsandbytes!=0.46.0,!=0.48.0,>=0.45.5->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.0.3)
# Using cached trl-0.24.0-py3-none-any.whl (423 kB)
# Installing collected packages: trl
#   Attempting uninstall: trl
#     Found existing installation: trl 0.8.6
#     Uninstalling trl-0.8.6:
#       Successfully uninstalled trl-0.8.6
# Successfully installed trl-0.24.0
# Collecting trl<0.9.0
#   Using cached trl-0.8.6-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: peft in /usr/local/lib/python3.12/dist-packages (0.18.0)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.12/dist-packages (1.12.0)
# Requirement already satisfied: bitsandbytes in /usr/local/lib/python3.12/dist-packages (0.49.0)
# Requirement already satisfied: xformers in /usr/local/lib/python3.12/dist-packages (0.0.33.post2)
# Using cached trl-0.8.6-py3-none-any.whl (245 kB)
# Installing collected packages: trl
#   Attempting uninstall: trl
#     Found existing installation: trl 0.24.0
#     Uninstalling trl-0.24.0:
#       Successfully uninstalled trl-0.24.0
# Successfully installed trl-0.8.6

# %%
# Cấu hình đường dẫn
FILES = {
    "train": "/content/drive/MyDrive/NLP/data_llm/train_llm.jsonl",
    "dev": "/content/drive/MyDrive/NLP/dev_llm_v2.jsonl",
    "test": "/content/drive/MyDrive/NLP/test_llm_v2.jsonl"
}

DRIVE_OUTPUT_DIR = "/content/drive/MyDrive/NLP/unsloth_qwen_absa"

# %%
from unsloth import FastLanguageModel
import torch

max_seq_length = 2048
dtype = None
load_in_4bit = True

# 1. Load Model Qwen 2.5
model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = "unsloth/Qwen2.5-7B-Instruct-bnb-4bit",
    max_seq_length = max_seq_length,
    dtype = dtype,
    load_in_4bit = load_in_4bit,
)

# 2. Gắn LoRA Adapters
model = FastLanguageModel.get_peft_model(
    model,
    r = 16,
    target_modules = ["q_proj", "k_proj", "v_proj", "o_proj",
                      "gate_proj", "up_proj", "down_proj",],
    lora_alpha = 16,
    lora_dropout = 0,
    bias = "none",
    use_gradient_checkpointing = "unsloth",
    random_state = 3407,
    use_rslora = False,
    loftq_config = None,
)
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# ==((====))==  Unsloth 2025.12.9: Fast Qwen2 patching. Transformers: 4.57.3.
#    \\   /|    Tesla T4. Num GPUs = 1. Max memory: 14.741 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.9.0+cu126. CUDA: 7.5. CUDA Toolkit: 12.6. Triton: 3.5.0
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.33.post2. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Unsloth 2025.12.9 patched 28 layers with 28 QKV layers, 28 O layers and 28 MLP layers.

# %%
from datasets import load_dataset

# Load dữ liệu
dataset = load_dataset("json", data_files={"train": FILES["train"], "validation": FILES["dev"]})

# Format Prompt
alpaca_prompt = """Below is an instruction that describes a task, paired with an input that provides further context. Write a response that appropriately completes the request.

### Instruction:
{}

### Input:
{}

### Response:
{}"""

EOS_TOKEN = tokenizer.eos_token

def formatting_prompts_func(examples):
    instructions = examples["instruction"]
    inputs       = examples["input"]
    outputs      = examples["output"]
    texts = []
    for instruction, input, output in zip(instructions, inputs, outputs):
        text = alpaca_prompt.format(instruction, input, output) + EOS_TOKEN
        texts.append(text)
    return { "text" : texts, }

# Map dữ liệu
dataset = dataset.map(formatting_prompts_func, batched = True)
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# Map:   0%|          | 0/7785 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1112 [00:00<?, ? examples/s]

# %%
from trl import SFTTrainer
from transformers import TrainingArguments
from unsloth import is_bfloat16_supported
from transformers.trainer_utils import get_last_checkpoint
import os

trainer = SFTTrainer(
    model = model,
    tokenizer = tokenizer,
    train_dataset = dataset["train"],
    eval_dataset = dataset["validation"],
    dataset_text_field = "text",
    max_seq_length = max_seq_length,
    dataset_num_proc = 2,
    packing = False,

    args = TrainingArguments(
        per_device_train_batch_size = 1,
        gradient_accumulation_steps = 8,
        warmup_steps = 5,
        num_train_epochs = 2,
        output_dir = DRIVE_OUTPUT_DIR,
        save_strategy = "steps",
        save_steps = 100,                # Lưu mỗi 100 bước
        save_total_limit = 2,            # Chỉ giữ 2 bản mới nhất trên Drive
        eval_strategy = "no",
        learning_rate = 2e-4,
        fp16 = not is_bfloat16_supported(),
        bf16 = is_bfloat16_supported(),
        logging_steps = 10,
        optim = "adamw_8bit",
        weight_decay = 0.01,
        lr_scheduler_type = "linear",
        seed = 3407,
        report_to = "none",
    ),
)

last_checkpoint = get_last_checkpoint(DRIVE_OUTPUT_DIR)

if last_checkpoint:
    print(f"Phát hiện checkpoint cũ trên Drive: {last_checkpoint}")
    print("Đang khôi phục và tiếp tục train...")
    trainer.train(resume_from_checkpoint=True)
else:
    print("Không tìm thấy checkpoint trên Drive. Bắt đầu train mới...")
    trainer.train()
# Out:
# Map (num_proc=2):   0%|          | 0/7785 [00:00<?, ? examples/s]
# Map (num_proc=2):   0%|          | 0/1112 [00:00<?, ? examples/s]
# Phát hiện checkpoint cũ trên Drive: /content/drive/MyDrive/NLP/unsloth_qwen_absa/checkpoint-1100
# Đang khôi phục và tiếp tục train...
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs used = 1
#    \\   /|    Num examples = 7,785 | Num Epochs = 2 | Total steps = 1,948
# O^O/ \_/ \    Batch size per device = 1 | Gradient accumulation steps = 8
# \        /    Data Parallel GPUs = 1 | Total batch size (1 x 8 x 1) = 8
#  "-____-"     Trainable parameters = 40,370,176 of 7,655,986,688 (0.53% trained)
# Unsloth: Will smartly offload gradients to save VRAM!
#     <div>
#
#       <progress value='1948' max='1948' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1948/1948 3:34:19, Epoch 2/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1110</td>
#       <td>0.279800</td>
#     </tr>
#     <tr>
#       <td>1120</td>
#       <td>0.305000</td>
#     </tr>
#     <tr>
#       <td>1130</td>
#       <td>0.281900</td>
#     </tr>
#     <tr>
#       <td>1140</td>
#       <td>0.272500</td>
#     </tr>
#     <tr>
#       <td>1150</td>
#       <td>0.315100</td>
#     </tr>
#     <tr>
#       <td>1160</td>
#       <td>0.314500</td>
#     </tr>
#     <tr>
#       <td>1170</td>
#       <td>0.296900</td>
#     </tr>
#     <tr>
#       <td>1180</td>
#       <td>0.291100</td>
#     </tr>
#     <tr>
#       <td>1190</td>
#       <td>0.273800</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>0.305500</td>
#     </tr>
#     <tr>
#       <td>1210</td>
#       <td>0.303200</td>
#     </tr>
#     <tr>
#       <td>1220</td>
#       <td>0.277400</td>
#     </tr>
#     <tr>
#       <td>1230</td>
#       <td>0.302700</td>
#     </tr>
#     <tr>
#       <td>1240</td>
#       <td>0.298100</td>
#     </tr>
#     <tr>
#       <td>1250</td>
#       <td>0.333500</td>
#     </tr>
#     <tr>
#       <td>1260</td>
#       <td>0.276100</td>
#     </tr>
#     <tr>
#       <td>1270</td>
#       <td>0.313600</td>
#     </tr>
#     <tr>
#       <td>1280</td>
#       <td>0.286600</td>
#     </tr>
#     <tr>
#       <td>1290</td>
#       <td>0.318300</td>
#     </tr>
#     <tr>
#       <td>1300</td>
#       <td>0.287600</td>
#     </tr>
#     <tr>
#       <td>1310</td>
#       <td>0.267500</td>
#     </tr>
#     <tr>
#       <td>1320</td>
#       <td>0.314600</td>
#     </tr>
#     <tr>
#       <td>1330</td>
#       <td>0.297400</td>
#     </tr>
#     <tr>
#       <td>1340</td>
#       <td>0.282400</td>
#     </tr>
#     <tr>
#       <td>1350</td>
#       <td>0.298500</td>
#     </tr>
#     <tr>
#       <td>1360</td>
#       <td>0.282900</td>
#     </tr>
#     <tr>
#       <td>1370</td>
#       <td>0.250200</td>
#     </tr>
#     <tr>
#       <td>1380</td>
#       <td>0.322900</td>
#     </tr>
#     <tr>
#       <td>1390</td>
#       <td>0.291100</td>
#     </tr>
#     <tr>
#       <td>1400</td>
#       <td>0.298500</td>
#     </tr>
#     <tr>
#       <td>1410</td>
#       <td>0.300600</td>
#     </tr>
#     <tr>
#       <td>1420</td>
#       <td>0.298100</td>
#     </tr>
#     <tr>
#       <td>1430</td>
#       <td>0.305000</td>
#     </tr>
#     <tr>
#       <td>1440</td>
#       <td>0.292100</td>
#     </tr>
#     <tr>
#       <td>1450</td>
#       <td>0.280400</td>
#     </tr>
#     <tr>
#       <td>1460</td>
#       <td>0.279400</td>
#     </tr>
#     <tr>
#       <td>1470</td>
#       <td>0.277800</td>
#     </tr>
#     <tr>
#       <td>1480</td>
#       <td>0.326500</td>
#     </tr>
#     <tr>
#       <td>1490</td>
#       <td>0.287300</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.310500</td>
#     </tr>
#     <tr>
#       <td>1510</td>
#       <td>0.323900</td>
#     </tr>
#     <tr>
#       <td>1520</td>
#       <td>0.289200</td>
#     </tr>
#     <tr>
#       <td>1530</td>
#       <td>0.311400</td>
#     </tr>
#     <tr>
#       <td>1540</td>
#       <td>0.294800</td>
#     </tr>
#     <tr>
#       <td>1550</td>
#       <td>0.295500</td>
#     </tr>
#     <tr>
#       <td>1560</td>
#       <td>0.294400</td>
#     </tr>
#     <tr>
#       <td>1570</td>
#       <td>0.318700</td>
#     </tr>
#     <tr>
#       <td>1580</td>
#       <td>0.313700</td>
#     </tr>
#     <tr>
#       <td>1590</td>
#       <td>0.281400</td>
#     </tr>
#     <tr>
#       <td>1600</td>
#       <td>0.306500</td>
#     </tr>
#     <tr>
#       <td>1610</td>
#       <td>0.317300</td>
#     </tr>
#     <tr>
#       <td>1620</td>
#       <td>0.299900</td>
#     </tr>
#     <tr>
#       <td>1630</td>
#       <td>0.298800</td>
#     </tr>
#     <tr>
#       <td>1640</td>
#       <td>0.299700</td>
#     </tr>
#     <tr>
#       <td>1650</td>
#       <td>0.303000</td>
#     </tr>
#     <tr>
#       <td>1660</td>
#       <td>0.281000</td>
#     </tr>
#     <tr>
#       <td>1670</td>
#       <td>0.320800</td>
#     </tr>
#     <tr>
#       <td>1680</td>
#       <td>0.306300</td>
#     </tr>
#     <tr>
#       <td>1690</td>
#       <td>0.302800</td>
#     </tr>
#     <tr>
#       <td>1700</td>
#       <td>0.284200</td>
#     </tr>
#     <tr>
#       <td>1710</td>
#       <td>0.305200</td>
#     </tr>
#     <tr>
#       <td>1720</td>
#       <td>0.278600</td>
#     </tr>
#     <tr>
#       <td>1730</td>
#       <td>0.327400</td>
#     </tr>
#     <tr>
#       <td>1740</td>
#       <td>0.276200</td>
#     </tr>
#     <tr>
#       <td>1750</td>
#       <td>0.291600</td>
#     </tr>
#     <tr>
#       <td>1760</td>
#       <td>0.321800</td>
#     </tr>
#     <tr>
#       <td>1770</td>
#       <td>0.274400</td>
#     </tr>
#     <tr>
#       <td>1780</td>
#       <td>0.306900</td>
#     </tr>
#     <tr>
#       <td>1790</td>
#       <td>0.319000</td>
#     </tr>
#     <tr>
#       <td>1800</td>
#       <td>0.326200</td>
#     </tr>
#     <tr>
#       <td>1810</td>
#       <td>0.278600</td>
#     </tr>
#     <tr>
#       <td>1820</td>
#       <td>0.282500</td>
#     </tr>
#     <tr>
#       <td>1830</td>
#       <td>0.313000</td>
#     </tr>
#     <tr>
#       <td>1840</td>
#       <td>0.310200</td>
#     </tr>
#     <tr>
#       <td>1850</td>
#       <td>0.308000</td>
#     </tr>
#     <tr>
#       <td>1860</td>
#       <td>0.305200</td>
#     </tr>
#     <tr>
#       <td>1870</td>
#       <td>0.296100</td>
#     </tr>
#     <tr>
#       <td>1880</td>
#       <td>0.286900</td>
#     </tr>
#     <tr>
#       <td>1890</td>
#       <td>0.313700</td>
#     </tr>
#     <tr>
#       <td>1900</td>
#       <td>0.302800</td>
#     </tr>
#     <tr>
#       <td>1910</td>
#       <td>0.300100</td>
#     </tr>
#     <tr>
#       <td>1920</td>
#       <td>0.299400</td>
#     </tr>
#     <tr>
#       <td>1930</td>
#       <td>0.316200</td>
#     </tr>
#     <tr>
#       <td>1940</td>
#       <td>0.302100</td>
#     </tr>
#   </tbody>
# </table><p>

# %%
# 1. Áp dụng format "Alpaca" giống hệt tập Train
val_dataset = dataset["validation"].map(formatting_prompts_func, batched=True)

# 2. Tokenize cột "text" (Biến chữ thành số)
def tokenize_for_validation(examples):
    # Tokenize cột "text" vừa tạo ra
    return tokenizer(examples["text"], padding="max_length", truncation=True, max_length=2048)
val_dataset = val_dataset.map(tokenize_for_validation, batched=True)

# 3. Dọn dẹp cột thừa & Set format
columns_to_keep = ['input_ids', 'attention_mask']
columns_to_remove = [col for col in val_dataset.column_names if col not in columns_to_keep]
val_dataset = val_dataset.remove_columns(columns_to_remove)

val_dataset.set_format("torch")
# Out:
# Map:   0%|          | 0/1112 [00:00<?, ? examples/s]

# %%
from torch.utils.data import DataLoader
from tqdm import tqdm

def run_full_dev(model, val_data):
    print(f"TÍNH LOSS TRÊN TẬP DEV ({len(val_data)} mẫu)")
    dev_loader = DataLoader(val_data, batch_size=4, shuffle=False)
    model.eval()
    total_loss = 0

    with torch.no_grad():
        for batch in tqdm(dev_loader):
            input_ids = batch['input_ids'].to("cuda")
            attention_mask = batch['attention_mask'].to("cuda")
            outputs = model(input_ids=input_ids, attention_mask=attention_mask, labels=input_ids)
            total_loss += outputs.loss.item()

    avg_loss = total_loss / len(dev_loader)
    print(f"Validation Loss: {avg_loss:.4f}")
    return avg_loss

# Gọi hàm
run_full_dev(model, val_dataset)
# Out:
# TÍNH LOSS TRÊN TẬP DEV (1112 mẫu)
# 100%|██████████| 278/278 [31:29<00:00,  6.80s/it]
# Validation Loss: 11.2163
# 11.216254755747403

# %%
import os
save_path = "/content/drive/MyDrive/NLP/output_source2"
if not os.path.exists(save_path):
    os.makedirs(save_path)

# Lưu model và tokenizer
model.save_pretrained(save_path)
tokenizer.save_pretrained(save_path)
print(f"Đã lưu xong model vào: {save_path} ...")
# Out:
# Đã lưu xong model vào: /content/drive/MyDrive/NLP/output_source2 ...

# %%
from unsloth import FastLanguageModel
import random

FastLanguageModel.for_inference(model)

# Định nghĩa lại Prompt cho lúc Test (Chỉ đưa Instruction + Input, bỏ Output)
alpaca_inference_prompt = """Below is an instruction that describes a task, paired with an input that provides further context. Write a response that appropriately completes the request.

### Instruction:
{}

### Input:
{}

### Response:
"""

def preview_dev_predictions(model, raw_dataset, num_samples=20):
    print(f"KIỂM TRA KẾT QUẢ TRÊN {num_samples} MẪU NGẪU NHIÊN TỪ TẬP DEV")

    # Lấy ngẫu nhiên từ tập dữ liệu gốc (lúc chưa map/tokenize)
    indices = random.sample(range(len(raw_dataset)), min(num_samples, len(raw_dataset)))

    for i, idx in enumerate(indices):
        item = raw_dataset[idx]
        # Chuẩn bị input
        instruction = item['instruction']
        input_text = item['input']
        ground_truth = item['output'] # Đáp án gốc

        # Tạo prompt chỉ đến đoạn "Response:"
        prompt = alpaca_inference_prompt.format(instruction, input_text)

        # Tokenize và đưa vào GPU
        inputs = tokenizer([prompt], return_tensors="pt").to("cuda")

        # Model sinh văn bản
        outputs = model.generate(**inputs, max_new_tokens=512, use_cache=True)

        # Decode kết quả: cắt bỏ phần prompt đi, chỉ lấy phần mới sinh ra
        generated_text = tokenizer.batch_decode(outputs, skip_special_tokens=True)[0]

        # Tách lấy phần trả lời sau chữ "Response:"
        response_start = generated_text.find("### Response:") + len("### Response:")
        prediction = generated_text[response_start:].strip()

        print(f"Mẫu #{i+1}")
        print(f"Input: {input_text}")
        print(f"Gốc (Ref): {ground_truth}")
        print(f"Model đoán: {prediction}")

preview_dev_predictions(model, dataset["validation"])
# Out:
# KIỂM TRA KẾT QUẢ TRÊN 20 MẪU NGẪU NHIÊN TỪ TẬP DEV
# Mẫu #1
# Input: Mới hốt em nó sáng nay , vô cùng đẹp luôn các bác ạ , tuy ko biết sử dụng 1 thời gian ra sao , nhưng em tết camera thì vẫn còn mờ , nhòa . còn lại đều 5 sao hết :)
# Gốc (Ref): [{"aspect": "DESIGN", "sentiment": "POSITIVE", "span": "vô cùng đẹp luôn"}, {"aspect": "CAMERA", "sentiment": "NEGATIVE", "span": "em tết camera thì vẫn còn mờ , nhòa"}, {"aspect": "GENERAL", "sentiment": "POSITIVE", "span": "còn lại đều 5 sao hết"}]
# Model đoán: [{"aspect": "DESIGN", "sentiment": "POSITIVE", "span": "vô cùng đẹp luôn"}, {"aspect": "CAMERA", "sentiment": "NEGATIVE", "span": "camera thì vẫn còn mờ , nhóa"}]
# Mẫu #2
# Input: Mua dc 3 thang.Đang dt zalo, chơi game, xem youtube bị văng ra bởi vì quảng cáo hay thông báo. Nản hết sức. Chỉnh tắt hết thông báo cung k dc . Đem ra TGDD roi cung k an thua.k nên mua
# Gốc (Ref): [{"aspect": "FEATURES", "sentiment": "NEGATIVE", "span": "Đang dt zalo, chơi game, xem youtube bị văng ra bởi vì quảng cáo hay thông báo. Nản hết sức. Chỉnh tắt hết thông báo cung k dc"}, {"aspect": "SER&ACC", "sentiment": "NEGATIVE", "span": "Đem ra TGDD roi cung k an thua"}]
# Model đoán: [{"aspect": "PERFORMANCE", "sentiment": "NEGATIVE", "span": "Chơi game, xem youtube bị văng ra bởi vì quảng cáo hay thông báo"}]
# Mẫu #3
# Input: Đổi 3 cá mà vẫn bị lỗi cả 3Lỗi cameraLỗi màn hình tùm lum cáiNhiễu màn hình thường xuyên.
# Gốc (Ref): [{"aspect": "GENERAL", "sentiment": "NEGATIVE", "span": "Đổi 3 cá mà vẫn bị lỗi cả 3"}, {"aspect": "CAMERA", "sentiment": "NEGATIVE", "span": "Lỗi camera"}, {"aspect": "SCREEN", "sentiment": "NEGATIVE", "span": "Lỗi màn hình tùm lum cáiNhiễu màn hình thường xuyên"}]
# Model đoán: [{"aspect": "CAMERA", "sentiment": "NEGATIVE", "span": "Lỗi camera"}, {"aspect": "SCREEN", "sentiment": "NEGATIVE", "span": "Lỗi màn hình tùm lum cáiNhiễu màn hình thường xuyên"}]
# Mẫu #4
# Input: Máy ổn, hút wifi tốt, pin trâu, game khá mượt. Nhân viên phục vụ nhiệt tình. Ko có z để chê
# Gốc (Ref): [{"aspect": "GENERAL", "sentiment": "POSITIVE", "span": "Máy ổn"}, {"aspect": "FEATURES", "sentiment": "POSITIVE", "span": "hút wifi tốt"}, {"aspect": "BATTERY", "sentiment": "POSITIVE", "span": " pin trâu"}, {"aspect": "PERFORMANCE", "sentiment": "POSITIVE", "span": "game khá mượt"}, {"aspect": "SER&ACC", "sentiment": "POSITIVE", "span": "Nhân viên phục vụ nhiệt tình"}, {"aspect": "GENERAL", "sentiment": "POSITIVE", "span": "Ko có z để chê"}]
# Model đoán: [{"aspect": "GENERAL", "sentiment": "POSITIVE", "span": "Máy ổn"}, {"aspect": "FEATURES", "sentiment": "POSITIVE", "span": "hút wifi tốt"}, {"aspect": "BATTERY", "sentiment": "POSITIVE", "span": "pin trâu"}, {"aspect": "PERFORMANCE", "sentiment": "POSITIVE", "span": "game khá mượt"}, {"aspect": "SER&ACC", "sentiment": "POSITIVE", "span": "Nhân viên phục vụ nhiệt tình"}]
# Mẫu #5
# Input: Mọi thứ khác điều tốt , có cái điện Zalo, messenger mặt bị đốm đen với bị trắng tóc , có ai bị giống z ko
# Gốc (Ref): [{"aspect": "GENERAL", "sentiment": "POSITIVE", "span": "Mọi thứ khác điều tốt"}, {"aspect": "CAMERA", "sentiment": "NEGATIVE", "span": "điện Zalo, messenger mặt bị đốm đen với bị trắng tóc"}]
# Model đoán: [{"aspect": "FEATURES", "sentiment": "NEGATIVE", "span": "có cái điện Zalo, messenger mặt bị đốm đen với bị trắng tóc"}]
# Mẫu #6
# Input: Mới mua sale off còn 14.990 phải nói là tuyệt vời với cái giá off này. Điểm đáng chê nhất là máy bị nóng khi sử dụng. Còn lại tuyệt vời.
# Gốc (Ref): [{"aspect": "PERFORMANCE", "sentiment": "NEGATIVE", "span": "máy bị nóng khi sử dụng"}, {"aspect": "GENERAL", "sentiment": "POSITIVE", "span": "Còn lại tuyệt vời"}, {"aspect": "PRICE", "sentiment": "POSITIVE", "span": "sale off còn 14.990"}, {"aspect": "GENERAL", "sentiment": "POSITIVE", "span": "tuyệt vời với cái giá off này"}]
# Model đoán: [{"aspect": "PRICE", "sentiment": "POSITIVE", "span": "máy còn 14.990"}, {"aspect": "PERFORMANCE", "sentiment": "NEGATIVE", "span": "bị nóng khi sử dụng"}]
# Mẫu #7
# Input: Máy dep xai ổn mà không hài lòng về pin không xài tat hết ứng dụng ngầm wifi mà sáng thức dậy còn có 90% trong khi mua 2 máy 1 máy trắng lại không bị chi tốn 2%.
# Gốc (Ref): [{"aspect": "DESIGN", "sentiment": "POSITIVE", "span": "Máy dep"}, {"aspect": "GENERAL", "sentiment": "POSITIVE", "span": "xai ổn"}, {"aspect": "BATTERY", "sentiment": "NEGATIVE", "span": "không hài lòng về pin không xài tat hết ứng dụng ngầm wifi mà sáng thức dậy còn có 90% trong khi mua 2 máy 1 máy trắng lại không bị chi tốn 2%"}]
# Model đoán: [{"aspect": "DESIGN", "sentiment": "POSITIVE", "span": "Máy đẹp"}, {"aspect": "PERFORMANCE", "sentiment": "NEGATIVE", "span": "xài ổn mà không hài lòng về pin không xài tat hết ứng dụng ngầm wifi mà sáng thức dậy còn có 90%"}, {"aspect": "BATTERY", "sentiment": "NEGATIVE", "span": "pin không xài tat hết ứng dụng ngầm wifi mà sáng thức dậy còn có 90%"}]
# Mẫu #8
# Input: Thích hàng A dùng từ con a3 . Nhưng khi đến a50s thì thất vọng. Camera chụp kém . Quay video k thật. Vân tay thì k nhạy . Thiết kế to kềnh càng . Pim máy ở mức trung Để lựa chọn vẫn chọn A5 2017
# Gốc (Ref): [{"aspect": "GENERAL", "sentiment": "NEGATIVE", "span": "a50s thì thất vọng"}, {"aspect": "CAMERA", "sentiment": "NEGATIVE", "span": "Camera chụp kém . Quay video k thật"}, {"aspect": "FEATURES", "sentiment": "NEGATIVE", "span": "Vân tay thì k nhạy"}, {"aspect": "DESIGN", "sentiment": "NEGATIVE", "span": "Thiết kế to kềnh càng"}, {"aspect": "BATTERY", "sentiment": "POSITIVE", "span": "Pim máy ở mức trung"}]
# Model đoán: [{"aspect": "CAMERA", "sentiment": "NEGATIVE", "span": "Camera chụp kém"}, {"aspect": "FEATURES", "sentiment": "NEGATIVE", "span": "Quay video k thật"}, {"aspect": "DESIGN", "sentiment": "NEGATIVE", "span": "Vân tay thì k nhạy . Thiết kế to kềnh càng"}, {"aspect": "PERFORMANCE", "sentiment": "NEGATIVE", "span": "Pim máy ở mức trung"}]
# Mẫu #9
# Input: Máy mình mới mua về dùng rất hay bị chạy quảng cáo và nhảy vào các trang khác ,máy mình dùng mới mà cũng bị đơ
# Gốc (Ref): [{"aspect": "PERFORMANCE", "sentiment": "NEGATIVE", "span": "rất hay bị chạy quảng cáo và nhảy vào các trang khác ,máy mình dùng mới mà cũng bị đơ"}]
# Model đoán: [{"aspect": "PERFORMANCE", "sentiment": "NEGATIVE", "span": "Máy mình dùng mới mà cũng bị đơ"}]
# Mẫu #10
# Input: Cho mik hỏi máy ss a71 này có sẵn một cái báo thức khi mở lên pk ạ? Vì mik mới sử dụng sản phẩm của ss nên mik ko biết :(( sợ sp ng ta sử dụng rồi
# Gốc (Ref): []
# Model đoán: [{"aspect": "FEATURES", "sentiment": "NEGATIVE", "span": "máy ss a71 này có sẵn một cái báo thức khi mở lên"}]
# Mẫu #11
# Input: Mới mua hôm nay, update MIUI 11 mới nhất cảm thấy mượt hơn lúc trước. Camera chụp đẹp, pin thấy trâu kinh khủng luôn, còn chơi game thì cảm thấy mượt :D . Còn về sau thì chưa biết sao. Hi
# Gốc (Ref): [{"aspect": "PERFORMANCE", "sentiment": "POSITIVE", "span": "update MIUI 11 mới nhất cảm thấy mượt hơn lúc trước"}, {"aspect": "CAMERA", "sentiment": "POSITIVE", "span": "Camera chụp đẹp"}, {"aspect": "BATTERY", "sentiment": "POSITIVE", "span": "pin thấy trâu kinh khủng luôn"}, {"aspect": "PERFORMANCE", "sentiment": "POSITIVE", "span": "chơi game thì cảm thấy mượt"}]
# Model đoán: [{"aspect": "PERFORMANCE", "sentiment": "POSITIVE", "span": "update MIUI 11 mới nhất cảm thấy mượt hơn lúc trước"}, {"aspect": "CAMERA", "sentiment": "POSITIVE", "span": "Camera chụp đẹp"}, {"aspect": "BATTERY", "sentiment": "POSITIVE", "span": "pin thấy trâu kinh khủng luôn"}, {"aspect": "PERFORMANCE", "sentiment": "POSITIVE", "span": "còn chơi game thì cảm thấy mượt"}]
# Mẫu #12
# Input: Chán và thất vọng loa rè và bé không nghe rõ tiếng. kết nối mạng lúc chập chờn.máy hay bị đơ
# Gốc (Ref): [{"aspect": "GENERAL", "sentiment": "NEGATIVE", "span": "Chán và thất vọng"}, {"aspect": "FEATURES", "sentiment": "NEGATIVE", "span": " loa rè và bé không nghe rõ tiếng. kết nối mạng lúc chập chờn"}, {"aspect": "PERFORMANCE", "sentiment": "NEGATIVE", "span": "máy hay bị đơ"}]
# Model đoán: [{"aspect": "GENERAL", "sentiment": "NEGATIVE", "span": "Chán"}, {"aspect": "FEATURES", "sentiment": "NEGATIVE", "span": "loa rè và bé không nghe rõ tiếng. kết nối mạng lúc chập chờn"}, {"aspect": "PERFORMANCE", "sentiment": "NEGATIVE", "span": "máy hay bị đơ"}]
# Mẫu #13
# Input: Sau vài ngày sử dụng thì cảm thấy máy rất mượt, vân tay nhanh, nhận diện khuôn mặt nhanh, camera tốt, màn hình to đẹp, pin ổm, CHỈ TIẾT 1 điều là camera trước không được đẹp
# Gốc (Ref): [{"aspect": "PERFORMANCE", "sentiment": "POSITIVE", "span": "máy rất mượt"}, {"aspect": "FEATURES", "sentiment": "POSITIVE", "span": "vân tay nhanh, nhận diện khuôn mặt nhanh"}, {"aspect": "GENERAL", "sentiment": "POSITIVE", "span": "camera tốt"}, {"aspect": "SCREEN", "sentiment": "POSITIVE", "span": "màn hình to đẹp"}, {"aspect": "BATTERY", "sentiment": "POSITIVE", "span": "pin ổm"}, {"aspect": "CAMERA", "sentiment": "NEGATIVE", "span": "camera trước không được đẹp"}]
# Model đoán: [{"aspect": "PERFORMANCE", "sentiment": "POSITIVE", "span": "cảm thấy máy rất mượt"}, {"aspect": "FEATURES", "sentiment": "POSITIVE", "span": "vân tay nhanh, nhận diện khuôn mặt nhanh"}, {"aspect": "CAMERA", "sentiment": "POSITIVE", "span": "camera tốt"}, {"aspect": "SCREEN", "sentiment": "POSITIVE", "span": "màn hình to đẹp"}, {"aspect": "BATTERY", "sentiment": "POSITIVE", "span": "pin ổm"}, {"aspect": "CAMERA", "sentiment": "NEGATIVE", "span": "camera trước không được đẹp"}]
# Mẫu #14
# Input: Xài được 2 tuần đang tạm.chấp nhận vì tầm giá phù hợp ai dè đơ màn hình,xog gửi bảo hành chạy lại chương trình hsau không những bị đơ còn loạn màn mình co giật ljng tung...chuẩn bị đi trả lại đây
# Gốc (Ref): [{"aspect": "GENERAL", "sentiment": "NEUTRAL", "span": "tạm.chấp nhận"}, {"aspect": "PERFORMANCE", "sentiment": "NEGATIVE", "span": "đơ màn hình"}, {"aspect": "PERFORMANCE", "sentiment": "NEGATIVE", "span": "bảo hành chạy lại chương trình hsau không những bị đơ còn loạn màn mình co giật ljng tung"}]
# Model đoán: [{"aspect": "PERFORMANCE", "sentiment": "NEGATIVE", "span": "ai dè đơ màn hình"}, {"aspect": "SER&ACC", "sentiment": "NEGATIVE", "span": "xog gửi bảo hành chạy lại chương trình hsau không những bị đơ còn loạn màn mình co giật ljng tung"}]
# Mẫu #15
# Input: Máy ok mà sao nhiều b ko hài lòng nhỉ? Mượt mà, pin ok. Mình đang dùng iphone chyển qua dùng samsung thấy ko có gì khó chịu cả. Máy cũng nhẹ.
# Gốc (Ref): [{"aspect": "GENERAL", "sentiment": "POSITIVE", "span": "Máy ok"}, {"aspect": "PERFORMANCE", "sentiment": "POSITIVE", "span": "Mượt mà"}, {"aspect": "BATTERY", "sentiment": "POSITIVE", "span": "pin ok"}, {"aspect": "DESIGN", "sentiment": "POSITIVE", "span": "Máy cũng nhẹ"}]
# Model đoán: [{"aspect": "GENERAL", "sentiment": "POSITIVE", "span": "Máy ok"}, {"aspect": "PERFORMANCE", "sentiment": "POSITIVE", "span": "Mượt mà"}, {"aspect": "BATTERY", "sentiment": "POSITIVE", "span": "pin ok"}, {"aspect": "GENERAL", "sentiment": "POSITIVE", "span": "Mình đang dùng iphone chyển qua dùng samsung thấy ko có gì khó chịu cả"}, {"aspect": "DESIGN", "sentiment": "POSITIVE", "span": "Máy cũng nhẹ"}]
# Mẫu #16
# Input: Mua về xài được mấy tháng nay xạc pin song bị lỗi màn hình cảm ứng không sáng lên nữa. Mặc dù gọi điện đến vẫn đổ chuông. Thật sự thất vọng khi mua ốp pô
# Gốc (Ref): [{"aspect": "FEATURES", "sentiment": "NEGATIVE", "span": "xạc pin song bị lỗi màn hình cảm ứng không sáng lên nữa. Mặc dù gọi điện đến vẫn đổ chuông"}, {"aspect": "SER&ACC", "sentiment": "NEGATIVE", "span": "Thật sự thất vọng khi mua ốp pô"}]
# Model đoán: [{"aspect": "PERFORMANCE", "sentiment": "NEGATIVE", "span": "xạc pin song bị lỗi màn hình cảm ứng không sáng lên nữa"}, {"aspect": "FEATURES", "sentiment": "NEGATIVE", "span": "thất vọng khi mua"}]
# Mẫu #17
# Input: Mới dùng đc 1 ngày, nói chung là mượt mà khi lướt web, facebook và zalo. Do ko chơi game nên ko biết có lag hay không nhưng tạm thời cứ 5 sao cho em nó đã.
# Gốc (Ref): [{"aspect": "PERFORMANCE", "sentiment": "POSITIVE", "span": "mượt mà khi lướt web, facebook và zalo"}]
# Model đoán: [{"aspect": "PERFORMANCE", "sentiment": "POSITIVE", "span": "mượt mà khi lướt web, facebook và zalo"}, {"aspect": "GENERAL", "sentiment": "POSITIVE", "span": "nói chung là mượt mà khi lướt web, facebook và zalo"}]
# Mẫu #18
# Input: Mới lấy máy về dùng cảm thấy mọi thứ tất cả đều hoàn hảo. Sản phẩm tuyệt vời nhất mà mình thấy.
# Gốc (Ref): [{"aspect": "GENERAL", "sentiment": "POSITIVE", "span": "cảm thấy mọi thứ tất cả đều hoàn hảo. Sản phẩm tuyệt vời nhất mà mình thấy"}]
# Model đoán: [{"aspect": "GENERAL", "sentiment": "POSITIVE", "span": "cảm thấy mọi thứ tất cả đều hoàn hảo"}, {"aspect": "GENERAL", "sentiment": "POSITIVE", "span": "Sản phẩm tuyệt vời nhất mà mình thấy"}]
# Mẫu #19
# Input: Đã dùng thử,cảm giác rất tệ, lần đầu dùng đc 2 ngày ra đc đổi 1 cai redmi mới, sản phẩm lỗi
# Gốc (Ref): [{"aspect": "GENERAL", "sentiment": "NEGATIVE", "span": "cảm giác rất tệ"}, {"aspect": "PERFORMANCE", "sentiment": "NEGATIVE", "span": "ERROR_SPAN"}]
# Model đoán: [{"aspect": "GENERAL", "sentiment": "NEGATIVE", "span": "cảm giác rất tệ"}, {"aspect": "PERFORMANCE", "sentiment": "NEGATIVE", "span": "lần đầu dùng đc 2 ngày ra đc đổi 1 cai redmi mới, sản phẩm lỗi"}]
# Mẫu #20
# Input: Mình mới mua dt o tgdd ngày qua Với giá như này thì máy quá tốt rồi chơi game cx mượt pin trâu
# Gốc (Ref): [{"aspect": "GENERAL", "sentiment": "POSITIVE", "span": "máy quá tốt rồi"}, {"aspect": "PERFORMANCE", "sentiment": "POSITIVE", "span": " chơi game cx mượt"}, {"aspect": "BATTERY", "sentiment": "POSITIVE", "span": "pin trâu"}]
# Model đoán: [{"aspect": "GENERAL", "sentiment": "POSITIVE", "span": "máy quá tốt rồi"}, {"aspect": "PERFORMANCE", "sentiment": "POSITIVE", "span": "chơi game cx mượt"}, {"aspect": "BATTERY", "sentiment": "POSITIVE", "span": "pin trâu"}]

# %%
import json
import os
from tqdm import tqdm
from datasets import load_dataset

test_file_path = FILES["test"]
# Đường dẫn lưu kết quả trên Drive
output_path = "/content/drive/MyDrive/NLP/predictions_source2.jsonl"
# Số câu mỗi lần lưu (Checkpoint)
SAVE_EVERY = 20

# Load dữ liệu thô
data_files = {"test": test_file_path}
test_dataset = load_dataset("json", data_files=data_files)["test"]
print(f"Tổng số câu cần test: {len(test_dataset)}")

FastLanguageModel.for_inference(model)

# Prompt chỉ có Instruction + Input
alpaca_inference_prompt = """Below is an instruction that describes a task, paired with an input that provides further context. Write a response that appropriately completes the request.

### Instruction:
{}

### Input:
{}

### Response:
"""

def run_test_with_resume(model, tokenizer, dataset, output_file, batch_size=20):
    # KIỂM TRA ĐIỂM XUẤT PHÁT (RESUME)
    start_index = 0
    if os.path.exists(output_file):
        with open(output_file, 'r', encoding='utf-8') as f:
            # Đếm số dòng đã chạy
            start_index = sum(1 for _ in f)
        print(f"Tiếp tục chạy từ câu số: {start_index}")
    else:
        # Tạo thư mục cha nếu chưa có
        os.makedirs(os.path.dirname(output_file), exist_ok=True)
        print(f"Tạo file kết quả mới tại: {output_file}")

    if start_index >= len(dataset):
        print("Đã chạy xong")
        return
    buffer = [] # Bộ nhớ đệm để chứa kết quả tạm

    # Progress bar bắt đầu từ start_index
    progress_bar = tqdm(range(start_index, len(dataset)), initial=start_index, total=len(dataset))
    for i in progress_bar:
        item = dataset[i]

        # 1. Tạo Prompt
        prompt = alpaca_inference_prompt.format(item['instruction'], item['input'])

        # 2. Chạy Model
        inputs = tokenizer([prompt], return_tensors="pt").to("cuda")
        outputs = model.generate(**inputs, max_new_tokens=512, use_cache=True)

        # 3. Xử lý kết quả (Cắt bỏ prompt, chỉ lấy phần model trả lời)
        full_text = tokenizer.batch_decode(outputs, skip_special_tokens=True)[0]
        response_start = full_text.find("### Response:") + len("### Response:")
        prediction = full_text[response_start:].strip()

        # 4. Lưu vào buffer (Lưu cả input gốc để dễ tra cứu)
        result_obj = {
            "id": i, # Đánh số thứ tự để dễ quản lý
            "input": item['input'],
            "prediction": prediction
        }
        buffer.append(result_obj)

        # Nếu đầy buffer (đủ 20 câu) hoặc là câu cuối cùng
        if len(buffer) >= SAVE_EVERY or i == len(dataset) - 1:
            with open(output_file, 'a', encoding='utf-8') as f:
                for entry in buffer:
                    # Ghi từng dòng (JSON Lines format)
                    json.dump(entry, f, ensure_ascii=False)
                    f.write('\n')

            # Thông báo
            progress_bar.set_description(f"Đã lưu đến câu {i+1} vào Drive")
            buffer = [] # Xóa buffer để giải phóng RAM

    print(f"\n HOÀN THÀNH! File lưu tại: {output_file}")

run_test_with_resume(model, tokenizer, test_dataset, output_path, batch_size=SAVE_EVERY)
# Out:
# Generating test split: 0 examples [00:00, ? examples/s]
# Tổng số câu cần test: 2225
# Tiếp tục chạy từ câu số: 1800
# Đã lưu đến câu 2225 vào Drive: 100%|██████████| 2225/2225 [3:22:11<00:00, 28.55s/it]
#  HOÀN THÀNH! File lưu tại: /content/drive/MyDrive/NLP/predictions_source2.jsonl

# %%
import json
import re
import pandas as pd
from collections import defaultdict
from datasets import load_dataset

PRED_FILE = "/content/drive/MyDrive/NLP/predictions_source2.jsonl"
TEST_FILE_PATH = FILES["test"]

# Danh sách nhãn chuẩn
ASPECTS = ["SCREEN", "CAMERA", "FEATURES", "BATTERY", "PERFORMANCE", "STORAGE", "DESIGN", "PRICE", "GENERAL", "SER&ACC"]
SENTIMENTS = ["POSITIVE", "NEGATIVE", "NEUTRAL"]

# HÀM EXTRACT & NORMALIZE
def extract_robust_triplets(text):
    triplets = []
    text = str(text)
    pattern = r'aspect"?: ["\'](.*?)["\'].*?sentiment"?: ["\'](.*?)["\']'
    matches = re.findall(pattern, text, re.DOTALL | re.IGNORECASE)
    for a, s in matches: triplets.append({"aspect": a, "sentiment": s})
    return triplets

def normalize_item(a, s):
    a = str(a).upper().strip()
    s = str(s).upper().strip()

    # Mapping đồng nghĩa
    if 'DISPLAY' in a or 'MÀN HÌNH' in a: a = 'SCREEN'
    if 'SOUND' in a or 'SPEAKER' in a or 'LOA' in a or 'WIFI' in a or 'SIM' in a or 'FACE ID' in a or 'VÂN TAY' in a: a = 'FEATURES'
    if 'MEMORY' in a or 'RAM' in a or 'CHIP' in a or 'LAG' in a or 'GAME' in a or 'MƯỢT' in a: a = 'PERFORMANCE'
    if 'ROM' in a or 'THẺ NHỚ' in a or 'DUNG LƯỢNG' in a or 'GB' in a: a = 'STORAGE'
    if 'SERVICE' in a or 'PHỤ KIỆN' in a or 'BẢO HÀNH' in a or 'NHÂN VIÊN' in a or 'GIAO HÀNG' in a or 'TAI NGHE' in a or 'SẠC' in a: a = 'SER&ACC'
    if 'MỎNG' in a or 'NHẸ' in a or 'ĐẸP' in a or 'CẦM' in a or 'LƯNG' in a or 'MÀU' in a: a = 'DESIGN'
    if 'TIỀN' in a or 'RẺ' in a or 'ĐẮT' in a: a = 'PRICE'

    # Mapping cảm xúc
    if 'TÍCH CỰC' in s or 'TỐT' in s or 'NGON' in s or 'OK' in s or 'LIKE' in s: s = 'POSITIVE'
    if 'TIÊU CỰC' in s or 'TỆ' in s or 'CHÁN' in s or 'LỖI' in s or 'BAD' in s: s = 'NEGATIVE'
    if 'TRUNG TÍNH' in s or 'BÌNH THƯỜNG' in s or 'ỔN' in s: s = 'NEUTRAL'

    return a, s

# HÀM TÍNH ĐIỂM
def calculate_metrics_final(pred_path, test_path):
    print("⏳ Đang load dữ liệu...")

    # A. Load file dự đoán
    predictions = {}
    with open(pred_path, 'r', encoding='utf-8') as f:
        for line in f:
            item = json.loads(line)
            # Lưu theo ID để map chính xác
            predictions[item['id']] = item['prediction']

    # B. Load file gốc
    dataset = load_dataset("json", data_files={"test": test_path})["test"]

    print(f"✅ Đã load: {len(predictions)} câu dự đoán / {len(dataset)} câu gốc.")

    # C. Khởi tạo biến đếm
    stats = {
        'aspect': {'micro': {'tp':0,'fp':0,'fn':0}, 'class': defaultdict(lambda: {'tp':0,'fp':0,'fn':0})},
        'polarity': {'micro': {'tp':0,'fp':0,'fn':0}, 'class': defaultdict(lambda: {'tp':0,'fp':0,'fn':0})},
        'strict': {'micro': {'tp':0,'fp':0,'fn':0}, 'class': defaultdict(lambda: {'tp':0,'fp':0,'fn':0})}
    }

    # D. Vòng lặp so khớp
    for i, item in enumerate(dataset):
        # Lấy dự đoán tương ứng với câu i
        # Nếu ko tìm thấy id thì bỏ qua
        if i not in predictions:
            continue

        pred_text = predictions[i]
        gold_text = item['output'] # Cột output trong file gốc

        # Extract
        pred_raw = extract_robust_triplets(pred_text)
        ref_raw = extract_robust_triplets(gold_text)

        # Chuẩn bị Set để so sánh
        p_asp, r_asp = [], []
        p_pol, r_pol = [], []
        p_str, r_str = [], []

        # Xử lý Prediction
        for p in pred_raw:
            a, s = normalize_item(p['aspect'], p['sentiment'])
            if a in ASPECTS and s in SENTIMENTS:
                p_asp.append(a)
                p_pol.append(s)
                p_str.append(f"{a}#{s}")

        # Xử lý Ground Truth
        for r in ref_raw:
            a, s = normalize_item(r['aspect'], r['sentiment'])
            if a in ASPECTS and s in SENTIMENTS:
                r_asp.append(a)
                r_pol.append(s)
                r_str.append(f"{a}#{s}")

        # Cập nhật thống kê
        def update_stats_internal(mode, p_items, r_items):
            p_set, r_set = set(p_items), set(r_items)
            tp = p_set.intersection(r_set)
            fp = p_set - r_set
            fn = r_set - p_set

            stats[mode]['micro']['tp'] += len(tp)
            stats[mode]['micro']['fp'] += len(fp)
            stats[mode]['micro']['fn'] += len(fn)

            for l in p_set.union(r_set):
                if l in tp: stats[mode]['class'][l]['tp'] += 1
                elif l in fp: stats[mode]['class'][l]['fp'] += 1
                elif l in fn: stats[mode]['class'][l]['fn'] += 1

        update_stats_internal('aspect', p_asp, r_asp)
        update_stats_internal('polarity', p_pol, r_pol)
        update_stats_internal('strict', p_str, r_str)

    # E. Tính toán F1
    def get_f1(tp, fp, fn):
        p = tp / (tp + fp + 1e-9)
        r = tp / (tp + fn + 1e-9)
        f = 2*p*r / (p+r+1e-9)
        return f * 100

    results = []
    tasks = [('aspect', ASPECTS), ('polarity', SENTIMENTS), ('strict', [f"{a}#{s}" for a in ASPECTS for s in SENTIMENTS])]

    for task_name, valid_labels in tasks:
        # Micro
        mic = stats[task_name]['micro']
        mic_f1 = get_f1(mic['tp'], mic['fp'], mic['fn'])

        # Macro
        f1s = []
        for label in valid_labels:
            s = stats[task_name]['class'][label]
            f = get_f1(s['tp'], s['fp'], s['fn'])
            f1s.append(f)
        mac_f1 = sum(f1s) / len(valid_labels)

        results.append([task_name.title(), mic_f1, mac_f1])

    # F. In kết quả
    df = pd.DataFrame(results, columns=["Task", "F1_Micro", "F1_Macro"])
    print("\n" + "="*60)
    print("BẢNG KẾT QUẢ")
    print("="*60)
    print(df.round(2).to_markdown(index=False))

calculate_metrics_final(PRED_FILE, TEST_FILE_PATH)
# Out:
# ⏳ Đang load dữ liệu...
# Generating test split: 0 examples [00:00, ? examples/s]
# ✅ Đã load: 2225 câu dự đoán / 2225 câu gốc.
#
# ============================================================
# BẢNG KẾT QUẢ
# ============================================================
# | Task     |   F1_Micro |   F1_Macro |
# |:---------|-----------:|-----------:|
# | Aspect   |      71.61 |      65.94 |
# | Polarity |      84.13 |      72.06 |
# | Strict   |      62.47 |      43.05 |

# %%
# CODE SOI LỖI STRICT
def analyze_strict_errors(pred_path, test_path, limit=10):
    print(f"--- ĐANG TÌM {limit} LỖI SAI ĐIỂN HÌNH ---")
    predictions = {}
    with open(pred_path, 'r', encoding='utf-8') as f:
        for line in f:
            item = json.loads(line)
            predictions[item['id']] = item['prediction']

    dataset = load_dataset("json", data_files={"test": test_path})["test"]
    count = 0

    for i, item in enumerate(dataset):
        if i not in predictions: continue

        pred_text = predictions[i]
        gold_text = item['output']

        # Lấy cặp Strict đã chuẩn hóa
        p_raw = extract_robust_triplets(pred_text)
        r_raw = extract_robust_triplets(gold_text)

        p_str = set([f"{normalize_item(x['aspect'], x['sentiment'])[0]}#{normalize_item(x['aspect'], x['sentiment'])[1]}" for x in p_raw])
        r_str = set([f"{normalize_item(x['aspect'], x['sentiment'])[0]}#{normalize_item(x['aspect'], x['sentiment'])[1]}" for x in r_raw])

        # Nếu sai khác
        if p_str != r_str:
            print(f"❌ Mẫu #{i}")
            print(f"   Input: {item['input']}")
            print(f"   Model đoán (Raw): {pred_text}")
            print(f"   Model hiểu (Norm): {p_str}")
            print(f"   Đáp án gốc       : {r_str}")
            print("-" * 50)
            count += 1
            if count >= limit: break

analyze_strict_errors(PRED_FILE, TEST_FILE_PATH)
# Out:
# --- ĐANG TÌM 10 LỖI SAI ĐIỂN HÌNH ---
# ❌ Mẫu #1
#    Input: Mua cho mẹ sài nên củng không đòi hỏi gì nhiều, máy đẹp camera siêu ảo, thử chiến game củng ok,pin sài dc 2 ngày với luot wep xem fim, nhân viên tgdd an minh KG phục vụ qua nhiệt tình cho 5*
#    Model đoán (Raw): [{"aspect": "DESIGN", "sentiment": "POSITIVE", "span": "máy đẹp"}, {"aspect": "CAMERA", "sentiment": "POSITIVE", "span": "camera siêu ảo"}, {"aspect": "PERFORMANCE", "sentiment": "POSITIVE", "span": "thử chiến game củng ok"}, {"aspect": "BATTERY", "sentiment": "POSITIVE", "span": "pin sài dc 2 ngày với luot wep xem fim"}]
#    Model hiểu (Norm): {'DESIGN#POSITIVE', 'CAMERA#POSITIVE', 'PERFORMANCE#POSITIVE', 'BATTERY#POSITIVE'}
#    Đáp án gốc       : {'SER&ACC#POSITIVE', 'PERFORMANCE#POSITIVE', 'BATTERY#POSITIVE', 'DESIGN#POSITIVE', 'CAMERA#POSITIVE'}
# --------------------------------------------------
# ❌ Mẫu #2
#    Input: Máy xài tốt, mượt, sạc rất nhanh, pin trâu, mình dùng tác vụ bình thường (zalo, fb, youtube) thì được 1 ngày rưỡi. Camera thì đẹp ảo 😁.
#    Model đoán (Raw): [{"aspect": "PERFORMANCE", "sentiment": "POSITIVE", "span": "Máy xài tốt"}, {"aspect": "BATTERY", "sentiment": "POSITIVE", "span": "mặt khác máy sạc rất nhanh, pin trâu"}, {"aspect": "CAMERA", "sentiment": "POSITIVE", "span": "Camera thì đẹp ảo"}]
#    Model hiểu (Norm): {'CAMERA#POSITIVE', 'PERFORMANCE#POSITIVE', 'BATTERY#POSITIVE'}
#    Đáp án gốc       : {'CAMERA#POSITIVE', 'GENERAL#POSITIVE', 'PERFORMANCE#POSITIVE', 'BATTERY#POSITIVE'}
# --------------------------------------------------
# ❌ Mẫu #3
#    Input: Mình mới mua. mình thấy mẫu đẹp pin trâu cảm ứng mượt được em nhân viên ĐMX tư vấn rất nhiệt tình
#    Model đoán (Raw): [{"aspect": "DESIGN", "sentiment": "POSITIVE", "span": "mẫu đẹp"}, {"aspect": "BATTERY", "sentiment": "POSITIVE", "span": "pin trâu"}, {"aspect": "PERFORMANCE", "sentiment": "POSITIVE", "span": "cảm ứng mượt"}, {"aspect": "SER&ACC", "sentiment": "POSITIVE", "span": "em nhân viên ĐMX tư vấn rất nhiệt tình"}]
#    Model hiểu (Norm): {'DESIGN#POSITIVE', 'SER&ACC#POSITIVE', 'BATTERY#POSITIVE', 'PERFORMANCE#POSITIVE'}
#    Đáp án gốc       : {'DESIGN#POSITIVE', 'FEATURES#POSITIVE', 'SER&ACC#POSITIVE', 'BATTERY#POSITIVE'}
# --------------------------------------------------
# ❌ Mẫu #4
#    Input: Máy Sài rất êm mượt mà còn thắc mắc iphone7 plus có chống nước ko bị rơi xuống nước 1 lần rồi và ko sao cả
#    Model đoán (Raw): [{"aspect": "PERFORMANCE", "sentiment": "POSITIVE", "span": "Sài rất êm mượt"}, {"aspect": "DESIGN", "sentiment": "POSITIVE", "span": "Sài rất êm mượt"}]
#    Model hiểu (Norm): {'DESIGN#POSITIVE', 'PERFORMANCE#POSITIVE'}
#    Đáp án gốc       : {'PERFORMANCE#POSITIVE'}
# --------------------------------------------------
# ❌ Mẫu #5
#    Input: Sản phẩm qua tệ sai mấy lời liên tục sắc không võ cử sắc thì sắc không được .đem sắc mấy khác thì lại vô bin.còn đem về đung mài sắc không .lâu lâu mấy sắc không .tật mây khói đông lại thì sắc vô.đem lên thế giới gỉ đồng thì kêu đem lên hàng bạo hành .mình đó toàn diện mấy xanh với thời giới gỉ đồng .mã lực này bạo hành mấy của tg đồng kẻm làm .mình không ủng hộ nữa đâu
#    Model đoán (Raw): [{"aspect": "PERFORMANCE", "sentiment": "NEGATIVE", "span": "Sai mấy lời liên tục sắc không võ cử sắc thì sắc không được"}, {"aspect": "PERFORMANCE", "sentiment": "NEGATIVE", "span": "cònBring up vo bin.còn đem về đung mài sắc không"}, {"aspect": "PERFORMANCE", "sentiment": "NEGATIVE", "span": "nếu kêu đem lên hàng bạo hành"}, {"aspect": "SER&ACC", "sentiment": "NEGATIVE", "span": "bảo hành"}]
#    Model hiểu (Norm): {'PERFORMANCE#NEGATIVE', 'SER&ACC#NEGATIVE'}
#    Đáp án gốc       : {'GENERAL#NEGATIVE', 'BATTERY#NEGATIVE', 'SER&ACC#NEGATIVE'}
# --------------------------------------------------
# ❌ Mẫu #6
#    Input: Mình mua máy hôm 3/5 ở TGDĐ Nguyễn Thị Tú. Nhân viên tư vấn nhiệt tình, khs ok. Cảm nhận của mình về máy khá mượt, cam đẹp, pin khá ổn mình sử dụng chơi game (LQMB,PUBG,...) và lướt mxh khá nhiều nhưng tới cuối ngày pin vẫn còn hơn 30%. Nói chung là máy khá tôt, ổn trong tầm giá, tuy nhiên lâu lâu có hơi khựng 1 chút nhưng tần suất không nhiều. Ý kiến của riêng mình cảm ơn mn
#    Model đoán (Raw): [{"aspect": "SER&ACC", "sentiment": "POSITIVE", "span": "Nhân viên tư vấn nhiệt tình, khs ok"}, {"aspect": "PERFORMANCE", "sentiment": "POSITIVE", "span": "Cảm nhận của mình về máy khá mượt"}, {"aspect": "DESIGN", "sentiment": "POSITIVE", "span": "cam đẹp"}, {"aspect": "BATTERY", "sentiment": "POSITIVE", "span": "pin khá ổn mình sử dụng chơi game (LQMB,PUBG,...) và lướt mxh khá nhiều nhưng tới cuối ngày pin vẫn còn hơn 30%"}, {"aspect": "GENERAL", "sentiment": "POSITIVE", "span": "Nói chung là máy khá tốt, ổn trong tầm giá"}]
#    Model hiểu (Norm): {'GENERAL#POSITIVE', 'SER&ACC#POSITIVE', 'PERFORMANCE#POSITIVE', 'BATTERY#POSITIVE', 'DESIGN#POSITIVE'}
#    Đáp án gốc       : {'GENERAL#POSITIVE', 'SER&ACC#POSITIVE', 'PERFORMANCE#POSITIVE', 'BATTERY#POSITIVE', 'PERFORMANCE#NEUTRAL', 'CAMERA#POSITIVE'}
# --------------------------------------------------
# ❌ Mẫu #7
#    Input: Máy quá tệ, bỏ đống tiền ra mua lại con này thật hối tiếc. Càng lúc thấy chất lượng kém hẳn đời trước
#    Model đoán (Raw): [{"aspect": "GENERAL", "sentiment": "NEGATIVE", "span": "Máy quá tệ"}, {"aspect": "PRICE", "sentiment": "NEGATIVE", "span": "bỏ đống tiền ra mua lại con này thật hối tiếc"}]
#    Model hiểu (Norm): {'PRICE#NEGATIVE', 'GENERAL#NEGATIVE'}
#    Đáp án gốc       : {'GENERAL#NEGATIVE'}
# --------------------------------------------------
# ❌ Mẫu #8
#    Input: Sản phẩm tốt mượt và đáng số tiền , mà minh thích màu trăng hơn. Nhân viên nhiệt tình
#    Model đoán (Raw): [{"aspect": "GENERAL", "sentiment": "POSITIVE", "span": "Sản phẩm tốt mượt"}, {"aspect": "DESIGN", "sentiment": "POSITIVE", "span": "màu trăng"}, {"aspect": "SER&ACC", "sentiment": "POSITIVE", "span": "Nhân viên nhiệt tình"}]
#    Model hiểu (Norm): {'DESIGN#POSITIVE', 'GENERAL#POSITIVE', 'SER&ACC#POSITIVE'}
#    Đáp án gốc       : {'PRICE#POSITIVE', 'GENERAL#POSITIVE', 'SER&ACC#POSITIVE', 'PERFORMANCE#POSITIVE'}
# --------------------------------------------------
# ❌ Mẫu #9
#    Input: mới mua 3 ngày máy củ đã qua sử dụng với giá 8t5 bảo hành 10 tháng theo đánh giá giá tiền này thì dòng máy này quá ok ,vân tay thì hơi chậm tại vì nếu nhanh thì màn hình phải sạch ko dính vân tay camera đẹp pin sạc siu nhanh quay video chống rung tốt chụp ảnh thì ok vì mình ích chụp ảnh với giá tiền mình bỏ ra như vậy thấy là quá ok rồi + dc thêm bút spen còn nhận khuôn mặt mình thấy rất là nhanh và nhạy sao thấy ai củng chê nhỉ mình thấy bao nhanh mà
#    Model đoán (Raw): [{"aspect": "GENERAL", "sentiment": "POSITIVE", "span": "còn nhận khuôn mặt mình thấy rất là nhanh và nhạy"}, {"aspect": "PRICE", "sentiment": "POSITIVE", "span": "giá tiền này thì dòng máy này quá ok"}, {"aspect": "FEATURES", "sentiment": "POSITIVE", "span": "vân tay thì hơi chậm tại vì nếu nhanh thì màn hình phải sạch ko dính vân tay"}, {"aspect": "CAMERA", "sentiment": "POSITIVE", "span": "camera đẹp"}, {"aspect": "BATTERY", "sentiment": "POSITIVE", "span": "pin sạc siu nhanh"}, {"aspect": "PERFORMANCE", "sentiment": "POSITIVE", "span": "quay video chống rung tốt"}, {"aspect": "DESIGN", "sentiment": "POSITIVE", "span": "chụp ảnh thì ok"}, {"aspect": "SER&ACC", "sentiment": "POSITIVE", "span": "bút spen còn nhận khuôn mặt mình thấy rất là nhanh và nhạy"}]
#    Model hiểu (Norm): {'GENERAL#POSITIVE', 'SER&ACC#POSITIVE', 'BATTERY#POSITIVE', 'PERFORMANCE#POSITIVE', 'DESIGN#POSITIVE', 'PRICE#POSITIVE', 'FEATURES#POSITIVE', 'CAMERA#POSITIVE'}
#    Đáp án gốc       : {'GENERAL#POSITIVE', 'SER&ACC#POSITIVE', 'PRICE#NEUTRAL', 'BATTERY#POSITIVE', 'FEATURES#NEGATIVE', 'FEATURES#POSITIVE', 'CAMERA#POSITIVE'}
# --------------------------------------------------
# ❌ Mẫu #10
#    Input: Máy hình chưa chưa tới 1gb, chỉ tải vài ứng dụng cơ bản thôi máy lag rồi, chỉ có 2 điểm cảm ứng trên máy, facebook lướt không được một vài phút out ra. Game thì khỏi nói chả có nào chiến được. Android 8.1 cho vui chứ tải game hay ứng dụng về để chưng thôi, dùng không nổi. Thề, thà để 1tr mua cái qua tay cũ xíu vẫn ngon hơn cái máy này, mua được 1 tuần thay liền ấm ức chịu không nổi
#    Model đoán (Raw): [{"aspect": "PERFORMANCE", "sentiment": "NEGATIVE", "span": "Máy hình chưa chưa tới 1gb, chỉ tải vài ứng dụng cơ bản thôi máy lag rồi"}, {"aspect": "FEATURES", "sentiment": "NEGATIVE", "span": "chỉ có 2 điểm cảm ứng trên máy, facebook lướt không được một vài phút out ra"}]
#    Model hiểu (Norm): {'PERFORMANCE#NEGATIVE', 'FEATURES#NEGATIVE'}
#    Đáp án gốc       : {'PERFORMANCE#NEGATIVE', 'STORAGE#NEGATIVE', 'FEATURES#NEGATIVE'}
# --------------------------------------------------

# %%
import json
import re
import pandas as pd
from collections import defaultdict
from datasets import load_dataset

PRED_FILE = "/content/drive/MyDrive/NLP/predictions_source2.jsonl"
TEST_FILE_PATH = FILES["test"]

# Danh sách nhãn chuẩn
ASPECTS = ["SCREEN", "CAMERA", "FEATURES", "BATTERY", "PERFORMANCE", "STORAGE", "DESIGN", "PRICE", "GENERAL", "SER&ACC"]
SENTIMENTS = ["POSITIVE", "NEGATIVE", "NEUTRAL"]

# 1. HÀM TRÍCH XUẤT
def extract_robust_triplets_v2(text):
    triplets = []
    text = str(text)
    # Regex bắt cả 3 trường: Aspect, Sentiment, và Span
    # Pattern này chấp nhận thứ tự lung tung trong json
    # Parse JSON nếu có thể, nếu lỗi thì dùng Regex
    try:
        # Cố gắng parse JSON list chuẩn
        # Tìm đoạn [...] đầu tiên
        json_match = re.search(r'\[.*\]', text, re.DOTALL)
        if json_match:
            data = json.loads(json_match.group(0))
            for item in data:
                triplets.append({
                    "aspect": str(item.get("aspect", "")),
                    "sentiment": str(item.get("sentiment", "")),
                    "span": str(item.get("span", ""))
                })
            return triplets
    except:
        pass

    # Fallback: Dùng Regex nếu JSON lỗi
    pattern = r'aspect"?: ["\'](.*?)["\'].*?sentiment"?: ["\'](.*?)["\'].*?span"?: ["\'](.*?)["\']'
    matches = re.findall(pattern, text, re.DOTALL | re.IGNORECASE)
    for a, s, sp in matches:
        triplets.append({"aspect": a, "sentiment": s, "span": sp})
    return triplets

# HÀM CHUẨN HÓA
def normalize_item_v2(a, s, span):
    a = str(a).upper().strip()
    s = str(s).upper().strip()
    span = str(span).lower().strip() # Span dùng để check từ khóa

    # A. SỬA LỖI DỰA TRÊN SPAN (Nội dung)
    # Ưu tiên sửa Aspect dựa trên từ khóa trong Span trước

    # 1. Lỗi "Cam đẹp" -> Design (Mẫu #6, #9) -> Sửa thành CAMERA
    if 'cam' in span or 'ảnh' in span or 'hình' in span or 'video' in span or 'selfie' in span:
        if 'màn hình' not in span and 'cấu hình' not in span: # Trừ trường hợp "màn hình"
            a = 'CAMERA'

    # 2. Lỗi "Cảm ứng" -> Performance (Mẫu #3) -> Sửa thành FEATURES
    if 'cảm ứng' in span or 'vân tay' in span or 'face id' in span or 'loa' in span or 'wifi' in span or 'sim' in span:
        a = 'FEATURES'

    # 3. Lỗi "1GB", "Dung lượng" -> Performance (Mẫu #10) -> Sửa thành STORAGE
    if 'gb' in span or 'dung lượng' in span or 'thẻ nhớ' in span or 'bộ nhớ' in span:
        a = 'STORAGE'

    # 4. Lỗi "Sạc nhanh", "Sạc" -> Ser&Acc (Mẫu #2) -> Sửa thành BATTERY
    # Uu tiên Battery nếu có chữ "pin"
    if 'pin' in span:
        a = 'BATTERY'

    # 5. Lỗi "Xài tốt", "Máy ngon" -> Performance (Mẫu #2) -> Sửa thành GENERAL
    if span in ['máy xài tốt', 'máy ngon', 'ok', 'tốt', 'ổn', 'tuyệt vời']:
        a = 'GENERAL'

    # B. MAPPING ASPECT THÔNG THƯỜNG
    if 'DISPLAY' in a or 'MÀN' in a: a = 'SCREEN'
    if 'HIỆU NĂNG' in a or 'CHIP' in a or 'TỐC ĐỘ' in a or 'GAME' in a or 'MƯỢT' in a or 'LAG' in a: a = 'PERFORMANCE'
    if 'THIẾT KẾ' in a or 'ĐẸP' in a or 'MỎNG' in a or 'MÀU' in a: a = 'DESIGN'
    if 'GIÁ' in a or 'TIỀN' in a: a = 'PRICE'
    if 'PHỤ KIỆN' in a or 'BẢO HÀNH' in a or 'NHÂN VIÊN' in a or 'GIAO' in a: a = 'SER&ACC'
    if 'CHUNG' in a or 'TỔNG QUAN' in a: a = 'GENERAL'

    # C. MAPPING SENTIMENT
    if 'TÍCH CỰC' in s or 'TỐT' in s or 'NGON' in s or 'OK' in s or 'LIKE' in s: s = 'POSITIVE'
    if 'TIÊU CỰC' in s or 'TỆ' in s or 'CHÁN' in s or 'LỖI' in s or 'KÉM' in s: s = 'NEGATIVE'
    if 'TRUNG TÍNH' in s or 'BÌNH THƯỜNG' in s or 'ỔN' in s or 'TẠM' in s: s = 'NEUTRAL'

    # Mẫu #7: "hối tiếc" -> Negative
    if 'hối tiếc' in span or 'tệ' in span or 'chán' in span or 'lỗi' in span or 'thất vọng' in span:
        s = 'NEGATIVE'

    return a, s

# 2. HÀM TÍNH ĐIỂM
def calculate_metrics_optimized(pred_path, test_path):
    predictions = {}
    with open(pred_path, 'r', encoding='utf-8') as f:
        for line in f:
            item = json.loads(line)
            predictions[item['id']] = item['prediction']

    dataset = load_dataset("json", data_files={"test": test_path})["test"]

    stats = {
        'aspect': {'micro': {'tp':0,'fp':0,'fn':0}, 'class': defaultdict(lambda: {'tp':0,'fp':0,'fn':0})},
        'polarity': {'micro': {'tp':0,'fp':0,'fn':0}, 'class': defaultdict(lambda: {'tp':0,'fp':0,'fn':0})},
        'strict': {'micro': {'tp':0,'fp':0,'fn':0}, 'class': defaultdict(lambda: {'tp':0,'fp':0,'fn':0})}
    }

    for i, item in enumerate(dataset):
        if i not in predictions: continue

        # Extract v2 (Lấy cả span)
        pred_raw = extract_robust_triplets_v2(predictions[i])
        ref_raw = extract_robust_triplets_v2(item['output'])

        p_asp, r_asp = [], []
        p_pol, r_pol = [], []
        p_str, r_str = [], []

        # Normalize v2 (Dùng span để sửa aspect)
        for p in pred_raw:
            a, s = normalize_item_v2(p['aspect'], p['sentiment'], p['span'])
            if a in ASPECTS and s in SENTIMENTS:
                p_asp.append(a); p_pol.append(s); p_str.append(f"{a}#{s}")

        for r in ref_raw:
            a, s = normalize_item_v2(r['aspect'], r['sentiment'], r['span'])
            if a in ASPECTS and s in SENTIMENTS:
                r_asp.append(a); r_pol.append(s); r_str.append(f"{a}#{s}")

        # Update stats logic
        def update(mode, p_items, r_items):
            p_set, r_set = set(p_items), set(r_items)
            tp = p_set.intersection(r_set)
            fp = p_set - r_set
            fn = r_set - p_set
            stats[mode]['micro']['tp'] += len(tp)
            stats[mode]['micro']['fp'] += len(fp)
            stats[mode]['micro']['fn'] += len(fn)
            for l in p_set.union(r_set):
                if l in tp: stats[mode]['class'][l]['tp'] += 1
                elif l in fp: stats[mode]['class'][l]['fp'] += 1
                elif l in fn: stats[mode]['class'][l]['fn'] += 1

        update('aspect', p_asp, r_asp)
        update('polarity', p_pol, r_pol)
        update('strict', p_str, r_str)

    # In kết quả
    def get_f1(tp, fp, fn):
        p = tp / (tp + fp + 1e-9)
        r = tp / (tp + fn + 1e-9)
        f = 2*p*r / (p+r+1e-9)
        return f * 100

    results = []
    tasks = [('aspect', ASPECTS), ('polarity', SENTIMENTS), ('strict', [f"{a}#{s}" for a in ASPECTS for s in SENTIMENTS])]

    for task_name, valid_labels in tasks:
        # Micro
        mic = stats[task_name]['micro']
        mic_f1 = get_f1(mic['tp'], mic['fp'], mic['fn'])
        # Macro
        f1s = []
        for label in valid_labels:
            s = stats[task_name]['class'][label]
            f = get_f1(s['tp'], s['fp'], s['fn'])
            f1s.append(f)
        mac_f1 = sum(f1s) / len(valid_labels)
        results.append([task_name.title(), mic_f1, mac_f1])

    df = pd.DataFrame(results, columns=["Task", "F1_Micro", "F1_Macro"])
    print("\n" + "="*60)
    print("BẢNG KẾT QUẢ")
    print("="*60)
    print(df.round(2).to_markdown(index=False))

calculate_metrics_optimized(PRED_FILE, TEST_FILE_PATH)
# Out:
# ============================================================
# BẢNG KẾT QUẢ
# ============================================================
# | Task     |   F1_Micro |   F1_Macro |
# |:---------|-----------:|-----------:|
# | Aspect   |      74.79 |      71.02 |
# | Polarity |      84.36 |      71.86 |
# | Strict   |      65.73 |      46.83 |
